# %% [markdown]
# # Crawling Tweets using an essential account (API v2):
# This short tutorial introduces you to a workaround to use tweepy Client to access tweets with your essential account. First make sure tweepy is installed and upgraded to the latest version.

# %%
 # !pip install tweepy
# or pip install tweepy --upgrade
import tweepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tweepy in c:\users\wq19573\appdata\roaming\python\python39\site-packages (4.12.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\wq19573\appdata\roaming\python\python39\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\wq19573\appdata\roaming\python\python39\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)

# %%
#create tweepy client using only bearer code (from your developer dashboard)
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAOZ0jgEAAAAAQSciwAxRpuxR0ifQM6ZHIfzwOJk%3DXUYCk5T41zziRJSA5vhMC6PKXjWIRyric0l1QltybGKi5DGAAE')

# %% [markdown]
# # Searching for tweets:
# ## By keyword:
# You can use now this client to search for specific tweets. Let's search for data science term in recent tweets.

# %%
# Replace with your own search query
query = 'data science'

tweets = client.search_recent_tweets(query=query)

for tweet in tweets.data:
    print(tweet.text)
    print ("=====")
# Out:
# RT @Strategy_Gal: Ready to reach the next rung of your #DataScience career ladder?
#
# There’s one rare skill that will get you light years ah…
# =====
# Want a high-paying Data Science / Analysis Job? - Build Projects,
#
# Here are Data Science Projects with Source Code to land a Job :
#
# -- Thread --
# =====
# Free dataset websites are meant for data science not data analytics:
#
# To solve this problem check out:
#
# Data World Real World Fake Data
#
# These data are great for building dashboards and visuals.
# =====
# RT @fabian_theis: Interested in a PhD in data science @TU_Muenchen eg in my or other labs? Munich Data Science Institute is offering Linde/…
# =====
# 🦊 FalconX is hiring Software Engineer
#
# 🌇 San Mateo, CA
# 💪 #python #machinelearning #scala #go #golang
#
# #tech #softwareengineer #jobs
# https://t.co/p5QGIHth7Q
# =====
# "Is Data Science dying?" by Rinu Gour. Follow our site https://t.co/6NaRNNqTrD for more such articles.
# Post link: https://t.co/UcKreLUmN7
# total likes: 1,061
# Reading Time: 2.7 mins
# #DataScience #BigData #MachineLearning #Data
# =====
# 📚 Proud to highlight the highly cited paper👏
# "Digital Twins and the Emerging Science of Self: Implications for Digital Health Experience Design and “Small” Data"
# by Steven M. Schwartz et al.
# Read it #openaccess here ➡️ https://t.co/NP2meLr9kY
#
# #DigitalPublicHealth
# #SmallData https://t.co/gYJbED9CAL
# =====
# RT @hasantoxr: MIT University offers a ton of free online courses.
#
# From Data Science to AI to starting a Start up.
#
# Here are 7 courses to…
# =====
# RT @ezekiel_aleke: Master Python and Data Science with these courses, Zero-to-Hero.
#
# Some give Certificate after completion.
#
# For absolutel…
# =====
# #DataScience 🤔
# Yes, you see that right.
#
# Catch our experts live for a case study where they decode the success streak of cricket teams using Data Science.
#
# Register now: https://t.co/aPa9u1cUob https://t.co/uquZZfC6QB
# =====

# %% [markdown]
# Note the following:
# - The tweets are only from the last 7 days
# - By default, in your response, you will only get the Tweet ID and Tweet text for each Tweet. If you need additional Tweet fields such as context_annotations, created_at (the time the tweet was created) etc., you can specifiy those fields using the tweet_fields parameter, as shown in the example below. Learn more about available fields here https://developer.twitter.com/en/docs/twitter-api/fields.
#
# - By default, a request returns 10 Tweets. If you want more than 10 Tweets per request, you can specify that using the max_results parameter. The maximum Tweets per request is 100.
#
# ### More tweets with more information:
# Let's specify more fields in tweet_fields parameter

# %%
query= 'data science'
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations','created_at','public_metrics'], max_results=100)

for tweet in tweets.data:
    print(tweet.created_at, tweet.text)
    print("Metrics",tweet.public_metrics)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
    print ("=======")
# Out:
# 2022-11-22 15:05:41+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:05:35+00:00 RT @ShamikaRavi: Conducting clinical trials only in India’s large cities is unlikely to sample the country’s ethnicity well enough. We prov…
# Metrics {'retweet_count': 1, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]
# =======
# 2022-11-22 15:05:25+00:00 @DexterRE1 @realEstateTrent MBA in finance here who did re private equity briefly. Most of career in computer sci and data science.
#
# How does comp sci impact strip malls? I think it is minimal. You could offer tenant a way to do targeted local online ads. You could build an app to keep track of cold calls
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '847544972781826048', 'name': 'Careers', 'description': 'Careers'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:05:19+00:00 RT @RoyalStatSoc: 📣We're now accepting applications for the Advanced Data Science Professional (ADSP) certification
#
# This new certification…
# Metrics {'retweet_count': 4, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:04:53+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:04:37+00:00 RT @ual_cci: Join us now for the online open day for BSc (Hons) Computer Science and BSc (Hons) Data Science and AI https://t.co/HfaieIpWZm
# Metrics {'retweet_count': 1, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:04:36+00:00 @benjyminty @Asirosa1 @Onebiskuit @ediz1975 @hcanna1 BC this is the ‘science’ our Councils are presenting us with.  It shouldn’t  be incumbent on the general public to prove whether LTNs are working.  Councils ignoring their OWN data clearly showing that many roads around LTNs are taking significant amounts of extra traffic.
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '1037076073719025664', 'name': 'Traffic', 'description': 'Traffic'}}]
# =======
# 2022-11-22 15:04:34+00:00 RT @simonholdorf: Are you interested in any of these topics?🔥
#
# - AWS, Azure, GCP ☁️
# - Linux 🐧
# - Certifications 🏆
# - DevOps 🛠️
# - Docker &amp; Kub…
# Metrics {'retweet_count': 764, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '1129034400069443584', 'name': 'DevOps'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1129034400069443584', 'name': 'DevOps'}}, {'domain': {'id': '45', 'name': 'Brand Vertical', 'description': 'Top level entities that describe a Brands industry'}, 'entity': {'id': '781974596706635776', 'name': 'Retail industry'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '783335558466506752', 'name': 'Online - Retail'}}, {'domain': {'id': '47', 'name': 'Brand', 'description': 'Brands and Companies'}, 'entity': {'id': '10026792024', 'name': 'Amazon'}}, {'domain': {'id': '48', 'name': 'Product', 'description': 'Products created by Brands.  Examples: Ford Explorer, Apple iPhone.'}, 'entity': {'id': '10040695083', 'name': 'Amazon Web Services (AWS)'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '848959431836487680', 'name': 'Linux', 'description': 'Linux'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848959431836487680', 'name': 'Linux', 'description': 'Linux'}}]
# =======
# 2022-11-22 15:04:32+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:04:31+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:04:27+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:04:21+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:04:19+00:00 RT @SBenzekry: [Tenure position] Eager to tackle real-world problems in clinical oncology by combining mechansitic modeling with data scien…
# Metrics {'retweet_count': 4, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# =======
# 2022-11-22 15:04:19+00:00 RT @davidhitt: SPACE JOB!
#
# NASA is going to OPEN SCIENCE – making our big data collections more accessible.
#
# My contract needs two comm pro…
# Metrics {'retweet_count': 3, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '872801340224806912', 'name': 'Aerospace', 'description': 'Aerospace'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557696420500541440', 'name': 'Automotive, Aircraft & Boat Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to automobile, spacecraft, aircraft and boat manufacturing'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '47', 'name': 'Brand', 'description': 'Brands and Companies'}, 'entity': {'id': '872802352448667648', 'name': 'NASA', 'description': 'NASA'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '854692455005921281', 'name': 'Science', 'description': 'Science'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '847899255880564736', 'name': 'Space', 'description': 'Space and astronomy'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '1118167720866930689', 'name': 'Big Data'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847899255880564736', 'name': 'Space', 'description': 'Space and astronomy'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '854692455005921281', 'name': 'Science', 'description': 'Science'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '872802352448667648', 'name': 'NASA', 'description': 'NASA'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1352681651516567553', 'name': 'Space agencies & companies'}}, {'domain': {'id': '164', 'name': 'Fields of study', 'description': 'for all fields of study, e.g., futurology, microbiology '}, 'entity': {'id': '854692455005921281', 'name': 'Science', 'description': 'Science'}}]
# =======
# 2022-11-22 15:03:57+00:00 @valenYB1 @Xypherz1 El partido de fútbol es solo una parte de todo el global pero que le voy a explicar a un pendejo que subestima la Data Science &amp; Big Data
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '1118167720866930689', 'name': 'Big Data'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}]
# =======
# 2022-11-22 15:03:52+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:03:42+00:00 UB professor awarded $665,000 grant to train underrepresented minorities in biomedical informatics and data science: https://t.co/JLwG9l7BWS https://t.co/gik7L09iuA
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '847896837532995585', 'name': 'Biology', 'description': 'Biology'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847529984717537280', 'name': 'Biotech and biomedical', 'description': 'Biotech and biomedical'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847896837532995585', 'name': 'Biology', 'description': 'Biology'}}]
# =======
# 2022-11-22 15:03:36+00:00 Conducting clinical trials only in India’s large cities is unlikely to sample the country’s ethnicity well enough. We provide some alternatives. Our forthcoming note in Current Science:
# https://t.co/pzxCDiZmBw
# Metrics {'retweet_count': 1, 'reply_count': 0, 'like_count': 5, 'quote_count': 0}
# [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]
# =======
# 2022-11-22 15:03:27+00:00 Leveraging big data enables you to drive faster, better decision-making. Learn everything about ingesting to building big data pipelines, here.
#
# 👉 https://t.co/sd34W9WYiv 👈
#
# #BigDataAnalytics #analytics #decisionmaking #Grazitti https://t.co/LpKLXNV70T
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '1118167720866930689', 'name': 'Big Data'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}]
# =======
# 2022-11-22 15:03:15+00:00 @Safarnejad_IR @darkdon21 @ZahraDana6 @Zodiko2 Your reality is more like a fantasy similar to the lord of the rings. My reality is based on science/data. By 2030 iran will face the worst drought in it’s history. No matter how much you love islam and pray, it would not fix the issue because your dear leader is stupid!
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557696802391859201', 'name': 'Entertainment & Leisure Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to movies, music, television, franchises, venues, theme parks, toys, tourism, hotels'}}, {'domain': {'id': '130', 'name': 'Multimedia Franchise', 'description': "Franchises which span multiple forms of media like 'Harry Potter'"}, 'entity': {'id': '1012755727998337024', 'name': 'The Lord of the Rings', 'description': 'This entity includes all conversation about the franchise, as well as any individual installments in the series, if applicable.\t\t\t '}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '839544274442051584', 'name': 'Entertainment'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1012755727998337024', 'name': 'The Lord of the Rings', 'description': 'This entity includes all conversation about the franchise, as well as any individual installments in the series, if applicable.\t\t\t '}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1074757527995277313', 'name': 'Entertainment franchises'}}]
# =======
# 2022-11-22 15:03:00+00:00 RT @VPrasadMDMPH: Don't question something that wasn't recommended pre pandemic due to bad data and has zero + cluster RCTs in kids, in hig…
# Metrics {'retweet_count': 263, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]
# =======
# 2022-11-22 15:02:59+00:00 Hoy es nuestro Bootcamp of Data Science &amp; Employability ⛔ ¿Aún no te has inscrito?
# 👉Clic aquí: https://t.co/JYJvBjOLfy
# 💻 Transmisión por Facebook Live &amp; Zoom
# 🎊 ¡Te esperamos!
#
# #datascience #datascientist #dataanalyst #dataengineer #dataarchitect #python #analisisdedatos #dsrp https://t.co/fjI1cEXk2U
# Metrics {'retweet_count': 0, 'reply_count': 1, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '781974596752842752', 'name': 'Services'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557696940178935808', 'name': 'Gaming Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to offline and online games such as gaming consoles, tabletop games, video game publishers'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '47', 'name': 'Brand', 'description': 'Brands and Companies'}, 'entity': {'id': '10029202045', 'name': 'Facebook'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10029202045', 'name': 'Facebook'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1196446161223028736', 'name': 'Social media'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1357506193879486469', 'name': 'Python'}}, {'domain': {'id': '165', 'name': 'Technology', 'description': 'for individual and types of technology, e.g., food technology, 3D printing'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '165', 'name': 'Technology', 'description': 'for individual and types of technology, e.g., food technology, 3D printing'}, 'entity': {'id': '1196446161223028736', 'name': 'Social media'}}]
# =======
# 2022-11-22 15:02:59+00:00 RT @DenisaCasement: "Facebook’s head of marketing science, Brad Smallwood... calls engagement data “irrelevant”, saying it has “no more cha…
# Metrics {'retweet_count': 2, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '781974596752842752', 'name': 'Services'}}, {'domain': {'id': '47', 'name': 'Brand', 'description': 'Brands and Companies'}, 'entity': {'id': '10029202045', 'name': 'Facebook'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10029202045', 'name': 'Facebook'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1196446161223028736', 'name': 'Social media'}}, {'domain': {'id': '165', 'name': 'Technology', 'description': 'for individual and types of technology, e.g., food technology, 3D printing'}, 'entity': {'id': '1196446161223028736', 'name': 'Social media'}}]
# =======
# 2022-11-22 15:02:54+00:00 RT @gp_pulipaka: Python for Data Science. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #PyTorch #Python #RStats #Tensor…
# Metrics {'retweet_count': 61, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '898657691010191360', 'name': 'Internet of things', 'description': 'Internet of Things'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '1118167720866930689', 'name': 'Big Data'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1357506193879486469', 'name': 'Python'}}, {'domain': {'id': '165', 'name': 'Technology', 'description': 'for individual and types of technology, e.g., food technology, 3D printing'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '898657691010191360', 'name': 'Internet of things', 'description': 'Internet of Things'}}]
# =======
# 2022-11-22 15:02:38+00:00 RT @ezekiel_aleke: Master Python and Data Science with these courses, Zero-to-Hero.
#
# Some give Certificate after completion.
#
# For absolutel…
# Metrics {'retweet_count': 495, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1357506193879486469', 'name': 'Python'}}, {'domain': {'id': '165', 'name': 'Technology', 'description': 'for individual and types of technology, e.g., food technology, 3D printing'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}]
# =======
# 2022-11-22 15:02:38+00:00 RT @simonholdorf: Data Science is among the most in-demand disciplines in 2023 &amp; beyond!
#
# Become a Data Scientist for free with these incre…
# Metrics {'retweet_count': 1281, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:02:20+00:00 RT @daansan_ml: @ThePeterMick Here is mine: https://t.co/VeQ6mEsG6W
#
# I talk about Machine Learning and Data Science concepts in a pill-size…
# Metrics {'retweet_count': 2, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:02:14+00:00 RT @daansan_ml: @ThePeterMick Here is mine: https://t.co/VeQ6mEsG6W
#
# I talk about Machine Learning and Data Science concepts in a pill-size…
# Metrics {'retweet_count': 2, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:02:05+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:01:39+00:00 @PoliticusSarah Or Elon is letting people express their freedom of speech? I trust science backed up with data. Do you not?
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# =======
# 2022-11-22 15:01:37+00:00 RT @mdancho84: Did you know that 80% of data science is spent cleaning &amp; preparing data? NOT modeling (the fun stuff).
#
# I made a short tut…
# Metrics {'retweet_count': 17, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 15:01:36+00:00 @World_Surfers @samanthamarika1 20 year olds??? Yeah, nope- not until recently. Maybe get your facts straight 😂 Soldiar of Science 😂😂😂 You know science requires you to actually look at the data. Sorry for that inconvenient update
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
# =======
# 2022-11-22 15:01:34+00:00 @Prathkum Learn data science and python
# Buy a house and a car
# Renovate my mom's house
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# ...
# =======
# 2022-11-22 14:53:09+00:00 RT @ChrisStaud: 1. Watch a full Python Data Science Course to learn programming with the best language for data science.
#
# FreeCodeCamp's 12…
# Metrics {'retweet_count': 31, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1357506193879486469', 'name': 'Python'}}, {'domain': {'id': '165', 'name': 'Technology', 'description': 'for individual and types of technology, e.g., food technology, 3D printing'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}]
# =======
# 2022-11-22 14:52:52+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 14:52:40+00:00 RT @ChrisStaud: Data science is in high demand, but the competition is tough.
#
# Here's a dead-simple guide to landing your first Data Scienc…
# Metrics {'retweet_count': 511, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 14:52:39+00:00 RT @CAMAOTEC: Kann der Einsatz von Künstlicher Intelligenz dabei helfen, unsere Kreativität zu steigern? Die Antwort gibt unser KI-Experte…
# Metrics {'retweet_count': 1, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# =======
# 2022-11-22 14:52:29+00:00 RT @bunsenbernerbmd: We are always doing the science to help out dog owners.
# Here is our data analysis of petting.
# (We have a very cool sci…
# Metrics {'retweet_count': 20, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# =======
# 2022-11-22 14:52:15+00:00 RT @sheffielduni: UK manufacturers will be able to cut energy bills, boost productivity and be more competitive with the launch of bleeding…
# Metrics {'retweet_count': 4, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1289190614207049728', 'name': 'Productivity'}}]
# =======
# 2022-11-22 14:52:06+00:00 RT @hasantoxr: MIT University offers a ton of free online courses.
#
# From Data Science to AI to starting a Start up.
#
# Here are 7 courses to…
# Metrics {'retweet_count': 1607, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1552291412820893697', 'name': 'Education Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to education such as colleges, school material, schools'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 14:51:59+00:00 wait omg omg drop the selfies mga ante! it's for science! do it for me pls kailangan ko po yung data para makagawa ng magandang r&amp;d ng research ko eme 😭 https://t.co/syejbUSYEg
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 2, 'quote_count': 0}
# [{'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '781974596752842752', 'name': 'Services'}}, {'domain': {'id': '48', 'name': 'Product', 'description': 'Products created by Brands.  Examples: Ford Explorer, Apple iPhone.'}, 'entity': {'id': '1412579054855671809', 'name': 'Google Innovation'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '854692455005921281', 'name': 'Science', 'description': 'Science'}}]
# =======
# 2022-11-22 14:51:50+00:00 RT @Sumanth_077: 5 Github repositories that will help you in your Data science and Machine Learning Journey: 🚀
# Metrics {'retweet_count': 195, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848921413196984320', 'name': 'Computer programming', 'description': 'Computer programming'}}, {'domain': {'id': '45', 'name': 'Brand Vertical', 'description': 'Top level entities that describe a Brands industry'}, 'entity': {'id': '781974597226799105', 'name': 'B2B'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '781974597172203520', 'name': 'Services - B2B'}}, {'domain': {'id': '47', 'name': 'Brand', 'description': 'Brands and Companies'}, 'entity': {'id': '10040692468', 'name': 'GitHub'}}]
# =======
# 2022-11-22 14:51:40+00:00 RT @freeCodeCamp: If you've ever struggled to find a dataset for a data science project, you're not alone.
#
# There's a useful way to get tha…
# Metrics {'retweet_count': 64, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 14:51:26+00:00 RT @hasantoxr: MIT University offers a ton of free online courses.
#
# From Data Science to AI to starting a Start up.
#
# Here are 7 courses to…
# Metrics {'retweet_count': 1607, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1552291412820893697', 'name': 'Education Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to education such as colleges, school material, schools'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}]
# =======
# 2022-11-22 14:50:58+00:00 One Assistant Professor, two Post Docs and four PhD positions available at IMDEA Networks Institute in Madrid @IMDEA_Networks. You can focus on data science, AI, cybersecurity, distributed ledger systems, LiFi technology, edge networks: https://t.co/TAZ5thMogK
# Metrics {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697333571112960', 'name': 'Technology Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to softwares, apps, communication equipments, hardwares'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '898650876658634752', 'name': 'Cybersecurity', 'description': 'Cybersecurity'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '930484568305541120', 'name': 'Data science', 'description': 'Data Science'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '848920371311001600', 'name': 'Technology', 'description': 'Technology and computing'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '898650876658634752', 'name': 'Cybersecurity', 'description': 'Cybersecurity'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '900740740468191232', 'name': 'Political issues', 'description': 'Political issues'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1047123725525479425', 'name': 'Information security', 'description': 'Information Security'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1088443224425807872', 'name': 'Information Privacy Worldwide', 'description': 'Information Privacy'}}]
# =======

# %% [markdown]
# ## Search by user:

# %%
# Replace with user twitter handler
query = 'from: elonmusk'

tweets = client.search_recent_tweets(query=query)

for tweet in tweets.data:
    print(tweet.text)
    print ("=====")
# Out:
# @BillyM2k the olden daze
# =====
# @jakeshieldsajj Indeed
# =====
# @R6BTuxYEfbGYIoB What do you mean?
# =====
# @WSJ @WSJopinion @AllysiaFinley .@CommunityNotes 🙌
# =====
# Wait, if I Tweet does that count as work?
# =====
# @SirineAti @Anc_Aesthetics Twitter
# =====
# @PPathole @Anc_Aesthetics Yeah, about 6 months ago
# =====
# @Syndicate I see a path
# =====
# @TeslaGong @CSMFHT It’s coming
# =====
# @teslaownersSV @CSMFHT Looking into it
# =====

# %% [markdown]
# ## Retrieve user ID and screen name

# %%
# the screen name of the user
screen_name = "elonmask"
# fetching the user
user= client.get_user(username= screen_name)
user.data.id
# Out:
# 1487148382225375235

# %% [markdown]
# ## Or the other way around

# %%
# the screen name of the user
user_ID = "2244994945"
# fetching the user
user= client.get_user(id= user_ID)
user.data.name
# Out:
# 'Twitter Dev'

# %%
user_id = '2244994945'

tweets = client.get_users_mentions(id=user_id, tweet_fields=['context_annotations','created_at','geo'])

for tweet in tweets.data:
    print(tweet)
# Out:
# @GaganHussain @elonmusk @Twitter @TwitterDev Yes 😂
# @Junaid59052867 @elonmusk @Twitter @TwitterDev 🤣🤣
# @MohammadShaadsk @elonmusk @Twitter @TwitterDev 🤣
# .@TwitterDev @Twitter should enable us to like mute an account for sometime. Like a snooze account feature or something.
#
# #Twitter2022
# #AI #Web3 #blockchain #DigitalTransformation #DataSecurity #5G #MachineLearning #reddit #WomenInSTEM #100DaysOfCode #dataScientist https://t.co/HGB133pLCd
#  #shopify #USA #realmeGTNeo3T
# @TwitterDev #RashamiDesai @theniyo #RIPTwitter #NZvINDonPrime #ChennaiSnow #KiaraAdvani
# @Yanky_Pollak @TPostMillennial @MythinformedMKE @elonmusk Please free @77BlueJays too. Thanks in advance. @Twitter @TwitterSupport @TwitterBlue @TwitterDev @TwitterEng @TwitterSafety #Twitter
# Not backing down till he’s free 💪🏻🫡🗣️
#
# #FreeShiLLin_ViLLian
# @TwitterSupport
# Case #: 0296460374
# @elonmusk @mayemusk @TwitterBlue @TwitterDev
# Wondering what are the key pain points for Manhattan w.r.t managing, scaling, maintenance and cost effectiveness against managed offerings ?
# @realGeorgeHotz @TwitterDev
# https://t.co/N28DBsqZ9l
# @IgorBrigadir @TwitterDev So frustrating. There goes a year of my life. :/ I know it is for you too.
# @Politwit1984 ¯\_(ツ)_/¯
# for what it's worth: nearly all the people i knew at @TwitterDev either got fired or left, and the few that remain, have no knowledge of any plans - literally nothing, no idea if the API will live or die or if it's even a thing that they're considering!

# %% [markdown]
# ## More than 100 tweets:

# %%
# Replace with your own search query
query = 'omicron -is:retweet' #exclude retweets
tweets= []

# Replace the limit=1000 with the maximum number of Tweets you want
for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
                              tweet_fields=['context_annotations', 'created_at','public_metrics'], max_results=100).flatten(limit=1000):
    tweets.append(tweet)

# %% [markdown]
# ## Saving as a dataframe:

# %%
import pandas as pd
tweet_df = pd.DataFrame()
tweet_df['text']= [tweet.text for tweet in tweets]
tweet_df['created_at']= [tweet.created_at for tweet in tweets]
tweet_df['ret_count']= [tweet.public_metrics['retweet_count'] for tweet in tweets]
tweet_df['like_count']= [tweet.public_metrics['like_count']for tweet in tweets]
tweet_df['source']= [tweet.source for tweet in tweets]


# tweet_df = pd.DataFrame(data=users_locs, 
#                     columns=['user', "location"])
tweet_df
# Out:
#                                                   text  \
# 0    Covid-19: Butantan detecta em São Paulo nova v...
# 1    #IDtwitter #Cellimmunity #Immunology emerging ...
# 2    You can spot a familiar face in this headline:...
# 3    @SaiyanBio Vous ne vous êtes pas mis 7 milliar...
# 4    #NuestrasNoticiasBajío📻\n#Internacional🌎 #Chin...
# ..                                                 ...
# 995  Covid: Nova linhagem da ômicron é detectada pe...
# 996  ฉีดวัคซีนโควิดกี่เข็ม? เข้าสู่โซนปลอดภัย ป้องก...
# 997  @K36335468 I'll explain why your arm hurts. Yo...
# 998  @billjohnstone16 @brianlilley This is exactly ...
# 999  @AvosGuacaMoles If you don't mind saying so, d...
#
#                    created_at  ret_count  like_count source
# 0   2022-11-22 15:11:26+00:00          0           0   None
# 1   2022-11-22 15:11:13+00:00          0           1   None
# 2   2022-11-22 15:09:57+00:00          0           0   None
# 3   2022-11-22 15:09:44+00:00          0           0   None
# 4   2022-11-22 15:09:10+00:00          0           0   None
# ..                        ...        ...         ...    ...
# 995 2022-11-22 05:05:56+00:00          0           0   None
# 996 2022-11-22 05:05:21+00:00          2           2   None
# 997 2022-11-22 05:05:01+00:00          0           2   None
# 998 2022-11-22 05:03:12+00:00          0           0   None
# 999 2022-11-22 05:02:53+00:00          0           0   None
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Searching for geo-tagged Tweets

# %%
# Replace with your own search query
query = 'covid -is:retweet place_country:US'

tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at', 'geo'],
                                  place_fields=['place_type', 'geo'], expansions='geo.place_id', max_results=100)

# Get list of places from includes object
places = {p["id"]: p for p in tweets.includes['places']}

for tweet in tweets.data:
    print(tweet.text)
    if places[tweet.geo['place_id']]:
        place = places[tweet.geo['place_id']]
        print(place.full_name)
    print ('=======')
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Input In [18], in <cell line: 4>()
#       1 # Replace with your own search query
#       2 query = 'covid -is:retweet place_country:US'
# ----> 4 tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at', 'geo'],
#       5                                   place_fields=['place_type', 'geo'], expansions='geo.place_id', max_results=100)
#       7 # Get list of places from includes object
#       8 places = {p["id"]: p for p in tweets.includes['places']}
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tweepy\client.py:1163, in Client.search_all_tweets(self, query, **params)
#    1071 """search_all_tweets( \
#    1072     query, *, end_time=None, expansions=None, max_results=None, \
#    1073     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1160 .. _pagination: https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/paginate
#    1161 """
#    1162 params["query"] = query
# -> 1163 return self._make_request(
#    1164     "GET", "/2/tweets/search/all", params=params,
#    1165     endpoint_parameters=(
#    1166         "end_time", "expansions", "max_results", "media.fields",
#    1167         "next_token", "place.fields", "poll.fields", "query",
#    1168         "since_id", "sort_order", "start_time", "tweet.fields",
#    1169         "until_id", "user.fields"
#    1170     ), data_type=Tweet
#    1171 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tweepy\client.py:129, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     123 def _make_request(
#     124     self, method, route, params={}, endpoint_parameters=(), json=None,
#     125     data_type=None, user_auth=False
#     126 ):
#     127     request_params = self._process_params(params, endpoint_parameters)
# --> 129     response = self.request(method, route, params=request_params,
#     130                             json=json, user_auth=user_auth)
#     132     if self.return_type is requests.Response:
#     133         return response
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tweepy\client.py:100, in BaseClient.request(self, method, route, params, json, user_auth)
#      98     raise Unauthorized(response)
#      99 if response.status_code == 403:
# --> 100     raise Forbidden(response)
#     101 if response.status_code == 404:
#     102     raise NotFound(response)
#
# Forbidden: 403 Forbidden
# When authenticating requests to the Twitter API v2 endpoints, you must use keys and tokens from a Twitter developer App that is attached to a Project. You can create a project via the developer portal.

# %% [markdown]
# --------------------

# %% [markdown]
# ## Important resources:
# - More information on Tweepy API v2 can be found here https://docs.tweepy.org/en/stable/client.html#
# - A comprehensive guide for using the Twitter API v2 with Tweepy in Python https://dev.to/twitterdev/a-comprehensive-guide-for-using-the-twitter-api-v2-using-tweepy-in-python-15d9
# - Alternatives to TweePy https://developer.twitter.com/en/docs/twitter-api/tools-and-libraries/v2
